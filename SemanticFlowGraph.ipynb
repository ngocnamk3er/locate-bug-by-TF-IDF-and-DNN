# %%
# !git clone https://github.com/ngocnamk3er/SemanticFlowGraph.git
# Out:
# fatal: destination path 'SemanticFlowGraph' already exists and is not an empty directory.

# %%
# !pwd
# Out:
# /content

# %%
# %cd SemanticFlowGraph
# Out:
# /content/SemanticFlowGraph

# %%
# !ls
# Out:
# environment-cpu.yml  LICENSE	      results		   run_files_ARCL.sh  run_hunks_ARC.sh
# environment-gpu.yml  model	      run_commits_ARCL.sh  run_files_ARC.sh   run_hunks_D.sh
# example.png	     README.md	      run_commits_ARC.sh   run_files_D.sh     SemanticFlowGraph
# INSTALL.md	     REQUIREMENTS.md  run_commits_D.sh	   run_hunks_ARCL.sh  STATUS.txt
