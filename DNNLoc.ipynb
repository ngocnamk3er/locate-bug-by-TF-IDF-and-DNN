# %%
# !git clone https://github.com/ngocnamk3er/dnn-loc-.git
# Out:
# Cloning into 'dnn-loc-'...
# remote: Enumerating objects: 232, done.
# remote: Counting objects: 100% (232/232), done.
# remote: Compressing objects: 100% (109/109), done.
# remote: Total 232 (delta 119), reused 231 (delta 118), pack-reused 0 (from 0)
# Receiving objects: 100% (232/232), 9.17 MiB | 10.76 MiB/s, done.
# Resolving deltas: 100% (119/119), done.

# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# dnn-loc-  sample_data

# %%
# %cd dnn-loc-
# Out:
# /content/dnn-loc-

# %%
# !python src/feature_extraction.py
# Out:
# Feature extraction
# {}
# Finished in 0.03987 secs.

# %%
# !python src/main.py
# Out:
# Traceback (most recent call last):
#   File "/content/dnn-loc-/src/main.py", line 5, in <module>
#     print(rsvm_model())
#           ^^^^^^^^^^^^
#   File "/content/dnn-loc-/src/rvsm_model.py", line 8, in rsvm_model
#     samples = csv2dict(FEATURE_PATH)
#               ^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/dnn-loc-/src/util.py", line 72, in csv2dict
#     with open(csv_path, "r") as f:
#          ^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: './data/Tomcat_features.csv'
